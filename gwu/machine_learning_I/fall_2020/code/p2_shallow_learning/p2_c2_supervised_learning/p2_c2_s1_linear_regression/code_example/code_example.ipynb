# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Notebook-Configuration" data-toc-modified-id="Notebook-Configuration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Notebook Configuration</a></span><ul class="toc-item"><li><span><a href="#Google-Drive" data-toc-modified-id="Google-Drive-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Google Drive</a></span></li><li><span><a href="#Warning" data-toc-modified-id="Warning-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Warning</a></span></li><li><span><a href="#Matplotlib" data-toc-modified-id="Matplotlib-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Matplotlib</a></span></li><li><span><a href="#TensorFlow" data-toc-modified-id="TensorFlow-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>TensorFlow</a></span></li><li><span><a href="#Random-Seed" data-toc-modified-id="Random-Seed-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Random Seed</a></span></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Loading-the-data" data-toc-modified-id="Loading-the-data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Loading the data</a></span></li><li><span><a href="#Dividing-the-training-data-into-training-and-validation" data-toc-modified-id="Dividing-the-training-data-into-training-and-validation-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Dividing the training data into training and validation</a></span></li><li><span><a href="#Handling-identifiers" data-toc-modified-id="Handling-identifiers-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Handling identifiers</a></span><ul class="toc-item"><li><span><a href="#Combining-the-training,-validation-and-test-data" data-toc-modified-id="Combining-the-training,-validation-and-test-data-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Combining the training, validation and test data</a></span></li><li><span><a href="#Identifying-identifiers" data-toc-modified-id="Identifying-identifiers-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Identifying identifiers</a></span></li><li><span><a href="#Removing-Identifiers" data-toc-modified-id="Removing-Identifiers-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Removing Identifiers</a></span></li></ul></li><li><span><a href="#Handling-missing-data" data-toc-modified-id="Handling-missing-data-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Handling missing data</a></span><ul class="toc-item"><li><span><a href="#Combining-the-training,-validation-and-test-data" data-toc-modified-id="Combining-the-training,-validation-and-test-data-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Combining the training, validation and test data</a></span></li><li><span><a href="#Identifying-missing-values" data-toc-modified-id="Identifying-missing-values-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Identifying missing values</a></span></li><li><span><a href="#Separating-the-training,-validation-and-test-data" data-toc-modified-id="Separating-the-training,-validation-and-test-data-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Separating the training, validation and test data</a></span></li><li><span><a href="#Imputing-missing-values" data-toc-modified-id="Imputing-missing-values-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Imputing missing values</a></span></li></ul></li><li><span><a href="#Encoding-the-data" data-toc-modified-id="Encoding-the-data-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Encoding the data</a></span><ul class="toc-item"><li><span><a href="#Combining-the-training,-validation-and-test-data" data-toc-modified-id="Combining-the-training,-validation-and-test-data-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Combining the training, validation and test data</a></span></li><li><span><a href="#Identifying-categorical-variables" data-toc-modified-id="Identifying-categorical-variables-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Identifying categorical variables</a></span></li><li><span><a href="#Encoding-categorical-features" data-toc-modified-id="Encoding-categorical-features-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Encoding categorical features</a></span></li><li><span><a href="#Separating-the-training,-validation-and-test-data" data-toc-modified-id="Separating-the-training,-validation-and-test-data-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Separating the training, validation and test data</a></span></li></ul></li><li><span><a href="#Scaling-the-data" data-toc-modified-id="Scaling-the-data-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Scaling the data</a></span></li><li><span><a href="#Getting-the-feature-matrix-and-target-vector" data-toc-modified-id="Getting-the-feature-matrix-and-target-vector-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Getting the feature matrix and target vector</a></span></li></ul></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Visualizing-the-2D-data" data-toc-modified-id="Visualizing-the-2D-data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Visualizing the 2D data</a></span></li><li><span><a href="#Visualizing-the-simple-linear-regression" data-toc-modified-id="Visualizing-the-simple-linear-regression-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Visualizing the simple linear regression</a></span></li><li><span><a href="#Visualizing-the-3D-data" data-toc-modified-id="Visualizing-the-3D-data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Visualizing the 3D data</a></span></li><li><span><a href="#Visualizing-the-multiple-linear-regression" data-toc-modified-id="Visualizing-the-multiple-linear-regression-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Visualizing the multiple linear regression</a></span></li><li><span><a href="#Sklearn-LinearRegression" data-toc-modified-id="Sklearn-LinearRegression-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Sklearn LinearRegression</a></span></li><li><span><a href="#Sklearn-SGDRegressor" data-toc-modified-id="Sklearn-SGDRegressor-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Sklearn SGDRegressor</a></span></li></ul></li><li><span><a href="#Training-Linear-Regression" data-toc-modified-id="Training-Linear-Regression-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Training Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Mean-squared-error-(MSE)" data-toc-modified-id="Mean-squared-error-(MSE)-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Mean squared error (MSE)</a></span></li><li><span><a href="#Surface-and-contour-Plot-of-MSE" data-toc-modified-id="Surface-and-contour-Plot-of-MSE-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Surface and contour Plot of MSE</a></span></li><li><span><a href="#The-Normal-Equation" data-toc-modified-id="The-Normal-Equation-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>The Normal Equation</a></span></li><li><span><a href="#Gradient-Descent" data-toc-modified-id="Gradient-Descent-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Gradient Descent</a></span><ul class="toc-item"><li><span><a href="#Batch-Gradient-Descent-(BGD)" data-toc-modified-id="Batch-Gradient-Descent-(BGD)-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Batch Gradient Descent (BGD)</a></span></li><li><span><a href="#Stochastic-Gradient-Descent-(SGD)" data-toc-modified-id="Stochastic-Gradient-Descent-(SGD)-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Stochastic Gradient Descent (SGD)</a></span></li><li><span><a href="#Mini-Batch-Gradient-Descent-(MBGD)" data-toc-modified-id="Mini-Batch-Gradient-Descent-(MBGD)-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Mini-Batch Gradient Descent (MBGD)</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <b>
#
# <p>
# <center>
# <font size="5">
# Popular Machine Learning Methods: Idea, Practice and Math
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size="4">
# Part 2, Chapter 2, Section 1: Linear Regression
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size="4">
# Code Example
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size="3">
# Data Science, Columbian College of Arts & Sciences, George Washington University
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size="3">
# Yuxiao Huang
# </font>
# </center>
# </p>
#
# </b>

# %% [markdown]
# # Overview

# %% [markdown]
# - This notebook includes the code example for Linear Regression (Part 2, Chapter 2, Section 1).
# - See the accompanied slides in

# %% [markdown]
# # Notebook Configuration

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
import sys

# Mount Google Drive
drive.mount('/content/drive')

# Get the absolute path of the current folder
abspath_curr = '/content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/p2_shallow_learning/p2_c2_supervised_learning/p2_c2_s1_linear_regression/code_example/'

# Get the absolute path of the shallow utilities folder
abspath_util_shallow = '/content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/utilities/p2_shallow_learning/'

# Get the absolute path of the shallow models folder
abspath_model_shallow = '/content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/models/p2_shallow_learning/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Warning

# %%
import warnings

# Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# Set matplotlib sizes
plt.rc('font', size=20)
plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rc('legend', fontsize=20)
plt.rc('figure', titlesize=20)

# %% [markdown]
# ## TensorFlow

# %%
# The magic below allows us to use tensorflow version 2.x
# %tensorflow_version 2.x 
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Random Seed

# %%
# The random seed
random_seed = 42

# Set random seed in tensorflow
tf.random.set_seed(random_seed)

# Set random seed in numpy
import numpy as np
np.random.seed(random_seed)

# %% [markdown]
# # Data Preprocessing

# %%
# Change working directory to the absolute path of the shallow utilities folder
# %cd $abspath_util_shallow

# Import the shallow utitilities
# %run pmlm_utilities_shallow.ipynb
# Out:
# /content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/utilities/p2_shallow_learning

# %% [markdown]
# ## Loading the data

# %% [markdown]
# In this code example, we will use the [House Prices (Advanced Regression Techniques) dataset](https://www.kaggle.com/c/house-prices-advanced-regression-techniques).

# %%
import pandas as pd

# Load the raw training data
df_raw_train = pd.read_csv(abspath_curr + 'data/house_prices_advanced_regression_techniques/train.csv',
                           header=0)
# Make a copy of df_raw_train
df_train = df_raw_train.copy(deep=True)

# Load the raw test data
df_raw_test = pd.read_csv(abspath_curr + 'data/house_prices_advanced_regression_techniques/test.csv',
                          header=0)
# Make a copy of df_raw_test
df_test = df_raw_test.copy(deep=True)

# Get the name of the target
target = 'SalePrice'

# %%
# Print the dimension of df_train
pd.DataFrame([[df_train.shape[0], df_train.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1460         81

# %%
# Print the dimension of df_test
pd.DataFrame([[df_test.shape[0], df_test.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1459         80

# %%
# Print the first 5 rows of df_train
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
# Print the first 5 rows of df_test
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Dividing the training data into training and validation
# The code below shows how to divide the training data into training (80%) and validation (20%).

# %%
from sklearn.model_selection import train_test_split

# Divide the training data into training (80%) and validation (20%)
df_train, df_val = train_test_split(df_train, train_size=0.8, random_state=random_seed)

# Reset the index
df_train, df_val = df_train.reset_index(drop=True), df_val.reset_index(drop=True)

# %%
# Print the dimension of df_train
pd.DataFrame([[df_train.shape[0], df_train.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1168         81

# %%
# Print the dimension of df_val
pd.DataFrame([[df_val.shape[0], df_val.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0     292         81

# %% [markdown]
# ## Handling identifiers

# %% [markdown]
# ### Combining the training, validation and test data
# The code below shows how to combine the training, validation and test data.

# %%
# Combine df_train, df_val and df_test
df = pd.concat([df_train, df_val, df_test], sort=False)

# %% [markdown]
# ### Identifying identifiers
# The code below shows how to find identifiers from data.

# %%
# Call id_checker on df
# See the implementation in pmlm_utilities.ipynb
df_id = id_checker(df)

# Print the first 5 rows of df_id
df_id.head()
# Out:
#      Id
# 0   255
# 1  1067
# 2   639
# 3   800
# 4   381

# %% [markdown]
# ### Removing Identifiers
# The code below shows how to remove identifiers from data.

# %%
import numpy as np

# Remove identifiers from df_train
df_train.drop(columns=np.intersect1d(df_id.columns, df_train.columns), inplace=True)

# Remove identifiers from df_val
df_val.drop(columns=np.intersect1d(df_id.columns, df_val.columns), inplace=True)

# Remove identifiers from df_test
df_test.drop(columns=np.intersect1d(df_id.columns, df_test.columns), inplace=True)

# %%
# Print the first 5 rows of df_train
df_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0          20       RL         70.0  ...        WD        Normal    145000
# 1          60       RL         59.0  ...        WD        Normal    178000
# 2          30       RL         67.0  ...        WD        Normal     85000
# 3          50       RL         60.0  ...        WD        Normal    175000
# 4          50       RL         50.0  ...        WD        Normal    127000
#
# [5 rows x 80 columns]

# %%
# Print the first 5 rows of df_val
df_val.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0          20       RL         70.0  ...        WD        Normal    154500
# 1          60       RL         98.0  ...        WD        Normal    325000
# 2          30       RM         56.0  ...        WD        Normal    115000
# 3          50       RM         50.0  ...        WD        Normal    159000
# 4          20       RL         89.0  ...        WD        Normal    315500
#
# [5 rows x 80 columns]

# %%
# Print the first 5 rows of df_test
df_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RH         80.0  ...    2010       WD        Normal
# 1          20       RL         81.0  ...    2010       WD        Normal
# 2          60       RL         74.0  ...    2010       WD        Normal
# 3          60       RL         78.0  ...    2010       WD        Normal
# 4         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Handling missing data

# %% [markdown]
# ### Combining the training, validation and test data
# The code below shows how to combine the training, validation and test data.

# %%
# Combine df_train, df_val and df_test
df = pd.concat([df_train, df_val, df_test], sort=False)

# %% [markdown]
# ### Identifying missing values

# %% [markdown]
# The code below shows how to find variables with NaN, their proportion of NaN and data type.

# %%
# Call nan_checker on df
# See the implementation in pmlm_utilities.ipynb
df_nan = nan_checker(df)

# Print df_nan
df_nan
# Out:
#              var  proportion    dtype
# 0         PoolQC    0.996574   object
# 1    MiscFeature    0.964029   object
# 2          Alley    0.932169   object
# 3          Fence    0.804385   object
# 4      SalePrice    0.499829  float64
# 5    FireplaceQu    0.486468   object
# 6    LotFrontage    0.166495  float64
# 7     GarageCond    0.054471   object
# 8    GarageYrBlt    0.054471  float64
# 9   GarageFinish    0.054471   object
# 10    GarageQual    0.054471   object
# 11    GarageType    0.053786   object
# 12  BsmtExposure    0.028092   object
# 13      BsmtCond    0.028092   object
# 14      BsmtQual    0.027749   object
# 15  BsmtFinType2    0.027407   object
# 16  BsmtFinType1    0.027064   object
# 17    MasVnrType    0.008222   object
# 18    MasVnrArea    0.007879  float64
# 19      MSZoning    0.001370   object
# 20    Functional    0.000685   object
# 21  BsmtHalfBath    0.000685  float64
# 22  BsmtFullBath    0.000685  float64
# 23     Utilities    0.000685   object
# ...

# %%
# Print the unique data type of variables with NaN
pd.DataFrame(df_nan['dtype'].unique(), columns=['dtype'])
# Out:
#      dtype
# 0   object
# 1  float64

# %% [markdown]
# The code below shows how to use data type to select variables with missing values in the combined data.

# %%
# Get the variables with missing values, their proportion of missing values and data type
df_miss = df_nan[df_nan['dtype'] == 'float64'].reset_index(drop=True)

# Print df_miss
df_miss
# Out:
#              var  proportion    dtype
# 0      SalePrice    0.499829  float64
# 1    LotFrontage    0.166495  float64
# 2    GarageYrBlt    0.054471  float64
# 3     MasVnrArea    0.007879  float64
# 4   BsmtHalfBath    0.000685  float64
# 5   BsmtFullBath    0.000685  float64
# 6    TotalBsmtSF    0.000343  float64
# 7      BsmtUnfSF    0.000343  float64
# 8     GarageCars    0.000343  float64
# 9     GarageArea    0.000343  float64
# 10    BsmtFinSF2    0.000343  float64
# 11    BsmtFinSF1    0.000343  float64

# %% [markdown]
# ### Separating the training, validation and test data
# The code below shows how to separate the training, validation and test data.

# %%
# Separating the training data
df_train = df.iloc[:df_train.shape[0], :]

# Separating the validation data
df_val = df.iloc[df_train.shape[0]:df_train.shape[0] + df_val.shape[0], :]

# Separating the test data
df_test = df.iloc[df_train.shape[0] + df_val.shape[0]:, :]

# %%
# Print the dimension of df_train
pd.DataFrame([[df_train.shape[0], df_train.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1168         80

# %%
# Print the dimension of df_val
pd.DataFrame([[df_val.shape[0], df_val.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0     292         80

# %%
# Print the dimension of df_test
pd.DataFrame([[df_test.shape[0], df_test.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1459         80

# %% [markdown]
# ### Imputing missing values
# The code below shows how to use the mean of a numerical feature to impute its missing values.

# %%
from sklearn.impute import SimpleImputer

# The SimpleImputer
si = SimpleImputer(missing_values=np.nan, strategy='mean')

# Impute the variables with missing values in df_train, df_val and df_test 
df_train[df_miss['var']] = si.fit_transform(df_train[df_miss['var']])
df_val[df_miss['var']] = si.transform(df_val[df_miss['var']])
df_test[df_miss['var']] = si.transform(df_test[df_miss['var']])

# %% [markdown]
# ## Encoding the data

# %% [markdown]
# ### Combining the training, validation and test data
# The code below shows how to combine the training, validation and test data.

# %%
# Combine df_train, df_val and df_test
df = pd.concat([df_train, df_val, df_test], sort=False)

# Print the unique data type of variables in df
pd.DataFrame(df.dtypes.unique(), columns=['dtype'])
# Out:
#      dtype
# 0    int64
# 1   object
# 2  float64

# %% [markdown]
# ### Identifying categorical variables

# %% [markdown]
# The code below shows how to find categorical variables (whose data type is dtype) and their number of unique value.

# %%
# Call cat_var_checker on df
# See the implementation in pmlm_utilities.ipynb
df_cat = cat_var_checker(df)

# Print the dataframe
df_cat
# Out:
#               var  nunique
# 0    Neighborhood       25
# 1     Exterior2nd       17
# 2     Exterior1st       16
# 3        SaleType       10
# 4      Condition1        9
# 5      Condition2        8
# 6        RoofMatl        8
# 7      Functional        8
# 8      HouseStyle        8
# 9    BsmtFinType2        7
# 10   BsmtFinType1        7
# 11     GarageType        7
# 12     Electrical        6
# 13     Foundation        6
# 14        Heating        6
# 15    FireplaceQu        6
# 16     GarageQual        6
# 17     GarageCond        6
# 18       MSZoning        6
# 19  SaleCondition        6
# 20      RoofStyle        6
# 21      ExterCond        5
# 22       BldgType        5
# 23    MiscFeature        5
# 24          Fence        5
# 25      LotConfig        5
# 26    KitchenQual        5
# 27       BsmtQual        5
# 28      HeatingQC        5
# 29     MasVnrType        5
# 30   BsmtExposure        5
# 31       BsmtCond        5
# 32      ExterQual        4
# ...

# %% [markdown]
# ### Encoding categorical features
# The code below shows how to encode categorical features in the combined data.

# %%
# One-hot-encode the categorical features in the combined data
df = pd.get_dummies(df, columns=np.setdiff1d(df_cat['var'], [target]))

# Print the first 5 rows of df
df.head()
# Out:
#    MSSubClass  LotFrontage  ...  Utilities_AllPub  Utilities_NoSeWa
# 0          20         70.0  ...                 1                 0
# 1          60         59.0  ...                 1                 0
# 2          30         67.0  ...                 1                 0
# 3          50         60.0  ...                 1                 0
# 4          50         50.0  ...                 1                 0
#
# [5 rows x 289 columns]

# %% [markdown]
# ### Separating the training, validation and test data
# The code below shows how to separate the training, validation and test data.

# %%
# Separating the training data
df_train = df.iloc[:df_train.shape[0], :]

# Separating the validation data
df_val = df.iloc[df_train.shape[0]:df_train.shape[0] + df_val.shape[0], :]

# Separating the test data
df_test = df.iloc[df_train.shape[0] + df_val.shape[0]:, :]

# %%
# Print the dimension of df_train
pd.DataFrame([[df_train.shape[0], df_train.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1168        289

# %%
# Print the dimension of df_val
pd.DataFrame([[df_val.shape[0], df_val.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0     292        289

# %%
# Print the dimension of df_test
pd.DataFrame([[df_test.shape[0], df_test.shape[1]]], columns=['# rows', '# columns'])
# Out:
#    # rows  # columns
# 0    1459        289

# %% [markdown]
# ## Scaling the data
# The code below shows how to standardize the data.

# %%
from sklearn.preprocessing import StandardScaler

# The StandardScaler
ss = StandardScaler()

# Standardize the training data
df_train = pd.DataFrame(ss.fit_transform(df_train), columns=df_train.columns)

# Standardize the validation data
df_val = pd.DataFrame(ss.transform(df_val), columns=df_val.columns)

# Standardize the test data
df_test = pd.DataFrame(ss.transform(df_test), columns=df_test.columns)

# %% [markdown]
# ## Getting the feature matrix and target vector

# %%
# Get the feature matrix
X_train = df_train[np.setdiff1d(df_train.columns, [target])]
X_val = df_val[np.setdiff1d(df_val.columns, [target])]
X_test = df_test[np.setdiff1d(df_test.columns, [target])]

# Get the target vector
y_train = df_train[target]
y_val = df_val[target]

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Visualizing the 2D data

# %% [markdown]
# The code below shows how to create the directory for the figures.

# %%
import os

# Make directory
directory = os.path.dirname(abspath_curr + 'result/figure/')
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# The code below shows how to draw the scatter plot between feature LotFrontage and target SalePrice

# %%
# The scatter plot between LotFrontage and SalePrice
plt.scatter(X_train[['LotFrontage']], y_train, color='green', edgecolor='white', s=100)

# Set x-axis
plt.xlabel('LotFrontage')

# Set y-axis
plt.ylabel(target)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/scatter_plot_LotFrontage_SalePrice.pdf')
plt.show()

# %% [markdown]
# ## Visualizing the simple linear regression

# %%
from sklearn.linear_model import LinearRegression

# The LinearRegression
lr_simple = LinearRegression()

# Train the simple linear regression with feature LotFrontage and target SalePrice
lr_simple.fit(X_train[['LotFrontage']], y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# The code below shows how to draw the scatter plot (between feature LotFrontage and target SalePrice) and line plot (between LotFrontage and predicted SalePrice).

# %%
# The scatter plot between LotFrontage and SalePrice
plt.scatter(X_train[['LotFrontage']], y_train, color='green', edgecolor='white', s=100)

# Get the prediction on the training data using lr
y_train_pred = lr_simple.predict(X_train[['LotFrontage']])

# The line plot
plt.plot(X_train[['LotFrontage']], y_train_pred, color='red', lw=3, alpha=0.6)  

# Set x-axis
plt.xlabel('LotFrontage')

# Set y-axis
plt.ylabel(target)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/simple_linear_regression_LotFrontage_SalePrice.pdf')
plt.show()

# %% [markdown]
# The code below shows how to draw the scatter plot (between feature LotFrontage and target SalePrice), a line plot (between LotFrontage and predicted SalePrice) and another line plot ($y$ = 4).

# %%
# The scatter plot between LotFrontage and SalePrice
plt.scatter(X_train[['LotFrontage']], y_train, color='green', edgecolor='white', s=100)

# Get the prediction on the training data using lr
y_train_pred = lr_simple.predict(X_train[['LotFrontage']])

# The line plot
plt.plot(X_train[['LotFrontage']], y_train_pred, color='red', lw=3, alpha=0.6)

# The line plot
plt.plot(X_train[['LotFrontage']], [4] * X_train.shape[0], color='black', lw=3, alpha=0.6)  

# Set x-axis
plt.xlabel('LotFrontage')

# Set y-axis
plt.ylabel(target)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/simple_linear_regression_LotFrontage_SalePrice_with_rival.pdf')
plt.show()

# %% [markdown]
# ## Visualizing the 3D data

# %% [markdown]
# The code below shows how to draw the scatter plot between features LotFrontage, LotArea and target SalePrice

# %%
from mpl_toolkits.mplot3d import Axes3D

# Create a figure
fig = plt.figure(figsize=(8.6, 5))

# Create the axes
ax = plt.axes(projection='3d', proj_type='ortho')

# The scatter plot between LotFrontage, LotArea and SalePrice
ax.scatter3D(X_train[['LotFrontage']], X_train[['LotArea']], y_train, color='green', edgecolor='white', s=100);

# Set x-axis
ax.set_xlabel('LotFrontage', labelpad=15)

# Set y-axis
ax.set_ylabel('LotArea', labelpad=15)

# Set z-axis
ax.set_zlabel(target, labelpad=5)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/scatter_plot_LotFrontage_LotArea_SalePrice.pdf')
plt.show()

# %% [markdown]
# ## Visualizing the multiple linear regression

# %%
# The LinearRegression
lr_multiple = LinearRegression()

# Train the multiple linear regression model with features LotFrontage, LotArea and target SalePrice
lr_multiple.fit(X_train[['LotFrontage', 'LotArea']], y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# The code below shows how to draw the scatter plot (between features LotFrontage, LotArea and target SalePrice) and surface plot (between LotFrontage, LotArea and predicted SalePrice).

# %%
from matplotlib import cm

# Create a figure
fig = plt.figure(figsize=(8.6, 5))

# Create the axes
ax = plt.axes(projection='3d', proj_type='ortho')

# Get x and y axes (LotFrontage and LotArea)
x, y = np.meshgrid(np.linspace(X_train[['LotFrontage']].min(), X_train[['LotFrontage']].max(), 20),
                   np.linspace(X_train[['LotArea']].min(), X_train[['LotArea']].max(), 20))

# Get z axis (predicted SalePrice)
z = lr_multiple.predict(np.hstack((x.reshape(-1, 1), y.reshape(-1, 1))))

# The surface plot between x, y and z
ax.plot_surface(x, y, z.reshape(x.shape), cmap=cm.coolwarm)

# The scatter plot between LotFrontage, LotArea and target
ax.scatter3D(X_train[['LotFrontage']], X_train[['LotArea']], y_train, color='green', edgecolor='white', s=100);

# Set x-axis
ax.set_xlabel('LotFrontage', labelpad=15)

# Set y-axis
ax.set_ylabel('LotArea', labelpad=15)

# Set z-axis
ax.set_zlabel('SalePrice', labelpad=5)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/multiple_linear_regression_LotFrontage_LotArea_SalePrice.pdf')
plt.show()

# %% [markdown]
# ## Sklearn LinearRegression
# The code below shows how to use sklearn LinearRegression for training and prediction.

# %%
from sklearn.linear_model import LinearRegression

# The LinearRegression
lr = LinearRegression()

# Train lr
lr.fit(X_train, y_train)

# Get the prediction on the validation data using lr
y_val_pred_lr = lr.predict(X_val)

# %% [markdown]
# ## Sklearn SGDRegressor
# The code below shows how to use sklearn SGDRegressor for training and prediction.

# %%
from sklearn.linear_model import SGDRegressor

# The SGDRegressor
sgdr = SGDRegressor()

# Train sgdr
sgdr.fit(X_train, y_train)

# Get the prediction on the validation data using sgdr
y_val_pred_sgdr = sgdr.predict(X_val)

# %% [markdown]
# # Training Linear Regression

# %%
# Change working directory to the absolute path of the shallow models folder
# %cd $abspath_model_shallow

# Import the shallow models
# %run pmlm_models_shallow.ipynb
# Out:
# /content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/models/p2_shallow_learning

# %% [markdown]
# ## Mean squared error (MSE)
# The code below shows how to use sklearn mean_squared_error to calculate MSE.

# %%
from sklearn.metrics import mean_squared_error

# %%
# Print the validation mean squared error with respect to LinearRegression
pd.DataFrame([mean_squared_error(y_val, y_val_pred_lr)], columns=['MSE'])
# Out:
#             MSE
# 0  6.217424e+20

# %%
# Print the validation mean squared error with respect to SGDRegressor
pd.DataFrame([mean_squared_error(y_val, y_val_pred_sgdr)], columns=['MSE'])
# Out:
#          MSE
# 0  15.192647

# %% [markdown]
# ## Surface and contour Plot of MSE

# %% [markdown]
# The code below shows how to draw the surface plot of training MSE of the simple linear regression (with feature LotFrontage and target SalePrice).

# %%
# Create a figure
fig = plt.figure(figsize=(8, 5))

# Create the axes
ax = plt.axes(projection='3d', proj_type='ortho')

# Get w0 and w1
w0, w1 = np.linspace(-5, 5, 100), np.linspace(-5, 5, 100)

# Get the x and y axes (w0 and w1)
x, y = np.meshgrid(w0, w1)

# Get the prediction on the training data
y_train_pred = np.dot(X_train[['LotFrontage']], y.reshape(1, -1)) + x.reshape(1, -1)

# Get the z axis (MSE)
z = np.sum((y_train_pred - np.array(y_train).reshape(-1, 1)) ** 2, axis=0) / X_train[['LotFrontage']].shape[0]

# The surface plot between x, y and z
ax.plot_surface(x, y, z.reshape(x.shape), cmap=cm.coolwarm)

# Set x-axis
ax.set_xlabel('$b$', labelpad=10)

# Set y-axis
ax.set_ylabel('$w$', labelpad=10)

# Set z-axis
ax.set_zlabel('$L(b, w)$', labelpad=5)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/obj_LotFrontage_SalePrice_surface.pdf')
plt.show()

# %% [markdown]
# The code below shows how to draw:
# - the surface plot of training MSE of the simple linear regression (with feature LotFrontage and target SalePrice)
# - the parameters of the simple linear regression and $y$ = 4

# %%
# Create a figure
fig = plt.figure(figsize=(8, 5))

# Create the axes
ax = plt.axes(projection='3d', proj_type='ortho')

# Get w0 and w1
w0, w1 = np.linspace(-5, 5, 100), np.linspace(-5, 5, 100)

# Get the x and y axes (w0 and w1)
x, y = np.meshgrid(w0, w1)

# Get the prediction on the training data
y_train_pred = np.dot(X_train[['LotFrontage']], y.reshape(1, -1)) + x.reshape(1, -1)

# Get the z axis (MSE)
z = np.sum((y_train_pred - np.array(y_train).reshape(-1, 1)) ** 2, axis=0) / X_train[['LotFrontage']].shape[0]

# The surface plot between x, y and z
ax.plot_surface(x, y, z.reshape(x.shape), cmap=cm.coolwarm)

# Set x-axis
ax.set_xlabel('$b$', labelpad=10)

# Set y-axis
ax.set_ylabel('$w$', labelpad=10)

# Set z-axis
ax.set_zlabel('$L(b, w)$', labelpad=5)

# Set tick label size
ax.tick_params(labelsize=20)

# Get the parameters of the simple linear regression
b, w = lr_simple.intercept_, lr_simple.coef_[0]
# Get the training mse
mse = mean_squared_error(y_train, lr_simple.predict(X_train[['LotFrontage']]))
# Add the parameters to the surface plot
ax.scatter3D(b, w, mse, s=500, color='red')

# Get the parameters of y = 4
b, w = 4, 0
# Get the training mse
mse = mean_squared_error(y_train, np.ones(y_train.shape[0]) * 4)
# Add the parameters to the surface plot
ax.scatter3D(4, 0, mse, s=200, color='black')

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/obj_LotFrontage_SalePrice_surface_with_dots.pdf')
plt.show()

# %% [markdown]
# The code below shows how to draw the contour plot of training MSE of the simple linear regression (with feature LotFrontage and target SalePrice).

# %%
# Create a figure
fig = plt.figure(figsize=(6, 5))

# Create the axes
ax = plt.axes()

# The contour plot between x, y and z
ax.contour(x, y, z.reshape(x.shape), [1, 2] + [5 * i for i in range(1, 20)], colors='green')

# Set x-axis
ax.set_xlabel('$b$')

# Set y-axis
ax.set_ylabel('$w$')

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/obj_LotFrontage_SalePrice_contour.pdf')
plt.show()

# %% [markdown]
# The code below shows how to draw:
# - the contour plot of training MSE of the simple linear regression (with feature LotFrontage and target SalePrice)
# - the parameters of the simple linear regression and $y$ = 4

# %%
# Create a figure
fig = plt.figure(figsize=(6, 5))

# Create the axes
ax = plt.axes()

# The contour plot between x, y and z
ax.contour(x, y, z.reshape(x.shape), [1, 2] + [5*i for i in range(1, 20)], colors='green')

# Set x-axis
ax.set_xlabel('$b$', fontsize=20)

# Set y-axis
ax.set_ylabel('$w$', fontsize=20)

# Set tick label size
ax.tick_params(labelsize=20)

# Get the parameters of the simple linear regression
b, w = lr_simple.intercept_, lr_simple.coef_[0]
# Add the parameters to the contour plot
ax.scatter(b, w, s=100, color='red')

# Get the parameters of y = 4
b, w = 4, 0
# Add the parameters to the contour plot
ax.scatter(b, w, s=100, color='black')

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/obj_LotFrontage_SalePrice_contour_with_dots.pdf')
plt.show()

# %% [markdown]
# ## The Normal Equation

# %% [markdown]
# The code below shows how to implement the linear regression using the normal equation.

# %%
# The LinearRegression_NE
# See the implementation in pmlm_models.ipynb
lr_ne = LinearRegression_NE()

# Train lr_ne
lr_ne.fit(X_train[['LotFrontage']], y_train)

# %%
# Print the loss (MSE)
pd.DataFrame([lr_ne.loss], columns=['MSE'])
# Out:
#        MSE
# 0  0.90257

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# ### Batch Gradient Descent (BGD)

# %% [markdown]
# The code below shows how to implement linear regression using batch gradient descent and regularization (lasso, ridge and elastic net).

# %%
# The LinearRegression_BGD
# See the implementation in pmlm_models.ipynb
lr_bgd = LinearRegression_BGD()

# Train lr_bgd
lr_bgd.fit(X_train[['LotFrontage']], y_train)

# %%
# Print the loss (MSE) in the last epoch
pd.DataFrame([lr_bgd.loss_train[-1]], columns=['MSE'])
# Out:
#        MSE
# 0  0.90437

# %% [markdown]
# The code below shows how to plot the loss as a function of the epoch.

# %%
# The line plot
plt.plot(range(100), lr_bgd.loss_train, color='red', lw=3, alpha=0.6)  

# Set x-axis
plt.xlabel('Epoch')

# Set y-axis
plt.ylabel('Loss')
plt.ylim([0.85, 1.07])

# Set the title
plt.title('BGD ($\eta=0.01$)')

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/lr_bgd_loss.pdf')
plt.show()

# %% [markdown]
# ### Stochastic Gradient Descent (SGD)

# %% [markdown]
# The code below shows how to implement linear regression using stochastic gradient descent and regularization (lasso, ridge and elastic net).

# %%
# The LinearRegression_SGD
# See the implementation in pmlm_models.ipynb
lr_sgd = LinearRegression_SGD()

# Train lr_sgd
lr_sgd.fit(X_train[['LotFrontage']], y_train)

# %%
# Print the loss (MSE) in the last epoch
pd.DataFrame([lr_sgd.loss_train[-1]], columns=['MSE'])
# Out:
#         MSE
# 0  0.976447

# %% [markdown]
# The code below shows how to plot the loss as a function of the epoch.

# %%
# The line plot
plt.plot(range(100), lr_sgd.loss_train, color='blue', lw=3, alpha=0.6)  

# Set x-axis
plt.xlabel('Epoch')

# Set y-axis
plt.ylabel('Loss')
plt.ylim([0.85, 1.07])

# Set the title
plt.title('SGD ($\eta=0.01$)')

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/lr_sgd_loss.pdf')
plt.show()

# %% [markdown]
# ### Mini-Batch Gradient Descent (MBGD)

# %% [markdown]
# The code below shows how to implement linear regression using mini-batch gradient descent and regularization (lasso, ridge and elastic net).

# %%
# The LinearRegression_MBGD
# See the implementation in pmlm_models.ipynb
lr_mbgd = LinearRegression_MBGD()

# Train lr_mbgd
lr_mbgd.fit(X_train[['LotFrontage']], y_train)

# %%
# Print the loss (MSE) in the last epoch
pd.DataFrame([lr_mbgd.loss_train[-1]], columns=['MSE'])
# Out:
#        MSE
# 0  0.88698

# %% [markdown]
# The code below shows how to plot the loss as a function of the epoch.

# %%
# The line plot
plt.plot(range(100), lr_mbgd.loss_train, color='green', lw=3, alpha=0.6)  

# Set x-axis
plt.xlabel('Epoch')

# Set y-axis
plt.ylabel('Loss')
plt.ylim([0.85, 1.07])

# Set the title
plt.title('MBGD ($\eta=0.01$)')

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + 'result/figure/lr_mbgd_loss.pdf')
plt.show()
